# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\jeesh\OneDrive\Documents\NARESHIT\DATA FILES\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %% [markdown]
# $numeical$ vs $numerical$

# %%
x=[1,2,3,4,5]
y=[1,2,3,4,5]

# %% [markdown]
# #### **plt.scatter**

# %%
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
x=[]
y=[]
for i in range(-4,5):
    x.append(i)
for i in x:
    y.append(i*i)
x,y
# Out:
# ([-4, -3, -2, -1, 0, 1, 2, 3, 4], [16, 9, 4, 1, 0, 1, 4, 9, 16])

# %%
x=[i for i in range(-4,5)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
#extract only numerical columnns
num_cols=visa_df.select_dtypes(exclude='object')
num_cols.columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
col1=visa_df['no_of_employees']
col2=visa_df['prevailing_wage']
plt.scatter(col1,col2)
plt.show()      #no relation

# %% [markdown]
# ### **pearson correlation coefficient**
#
# - r various from -1 to 1
#
# - -1 to 0 : negative relation
#
# -  0 to 1 : positive relation
#
# -  0      : no relation

# %% [markdown]
# <img src="https://th.bing.com/th/id/R.d0013b200465a5bfea12101205964dc1?rik=EwDM2XQ4ckHBuA&amp;riu=http%3a%2f%2f1algo1week.warriorkitty.com%2fassets%2fpearson-correlation-coefficient%2fpearson-formula.png&amp;ehk=gLrfZqX10ocNEHuo9UN%2fpsrUfY3uh%2butNtVfJv3c1pQ%3d&amp;risl=&amp;pid=ImgRaw&amp;r=0" alt="Pearson correlation coefficient" class=" nofocus" tabindex="0" aria-label="Pearson correlation coefficient" role="button" data-bm="6">

# %% [markdown]
# <img src="https://th.bing.com/th/id/R.d0013b200465a5bfea12101205964dc1?rik=EwDM2XQ4ckHBuA&amp;riu=http%3a%2f%2f1algo1week.warriorkitty.com%2fassets%2fpearson-correlation-coefficient%2fpearson-formula.png&amp;ehk=gLrfZqX10ocNEHuo9UN%2fpsrUfY3uh%2butNtVfJv3c1pQ%3d&amp;risl=&amp;pid=ImgRaw&amp;r=0" alt="Pearson correlation coefficient" class=" nofocus" tabindex="0" aria-label="Pearson correlation coefficient" role="button" data-bm="6">

# %% [markdown]
# <img src="https://th.bing.com/th/id/R.d0013b200465a5bfea12101205964dc1?rik=EwDM2XQ4ckHBuA&amp;riu=http%3a%2f%2f1algo1week.warriorkitty.com%2fassets%2fpearson-correlation-coefficient%2fpearson-formula.png&amp;ehk=gLrfZqX10ocNEHuo9UN%2fpsrUfY3uh%2butNtVfJv3c1pQ%3d&amp;risl=&amp;pid=ImgRaw&amp;r=0" alt="Pearson correlation coefficient" class=" nofocus" tabindex="0" aria-label="Pearson correlation coefficient" role="button" data-bm="611">

# %%
visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
col1=visa_df['yr_of_estab']
col2=visa_df['prevailing_wage']
plt.scatter(col1,col2)
plt.show()

# %%
path='winequality_red - winequality_red.csv'
wine=pd.read_csv(path)
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               NaN               NaN          NaN             NaN        NaN
# 1               7.4             0.700         0.00             1.9      0.076
# 2               NaN               NaN          NaN             NaN        NaN
# 3               7.8             0.880         0.00             2.6      0.098
# 4               NaN               NaN          NaN             NaN        NaN
# ...             ...               ...          ...             ...        ...
# 3193            6.3             0.510         0.13             2.3      0.076
# 3194            NaN               NaN          NaN             NaN        NaN
# 3195            5.9             0.645         0.12             2.0      0.075
# 3196            NaN               NaN          NaN             NaN        NaN
# 3197            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
col1=wine['fixed acidity']
col2=wine['citric acid']
plt.scatter(col1,col2)
plt.show()

# %%
col1=wine['fixed acidity']
col2=wine['pH']
plt.scatter(col1,col2)
plt.show()

# %% [markdown]
# ## $heat$-$map$

# %% [markdown]
# - heat map is useful to visualization of matrix
#
# - it is under seaborn packages
#
# - heat map will varies the values and give the colour abou the values

# %%
corr_visa=visa_df.corr(numeric_only=True)
corr_visa
#this is a matrix we want apply a heat map
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
sns.heatmap(corr_visa,
            annot=True)
plt.show()

# %%
corr_wine=wine.corr(numeric_only=True)
corr_wine
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr_wine,annot=True)
plt.show()

# %% [markdown]
# **new notebook**
# **new session**

# %%
visa_df.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %% [markdown]
# - in machine learning it us very imp to convert categorical data to numerical data
#
# - machine learning models develop by maths
#
# - machine learning takes the input in the form of numbers only
#
# - to convert the we have some enconding techniques
#
# - label encoder
#
#     - map
#
#     - np.where
#
#     - using sklearn package : label encoder
#
# - one hot encoder
#         - using pandas package : pd.get_dummies

# %%
#map

#- before applying map method first get the unique labels of the column

#- for ex case_status is a categorical column

#- it has two

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
d={'Certified':0,'Denied':1}
visa_df['case_status']=visa_df['case_status'].map(d)
#lhs is nothing bus creating a cloumn

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
d={}
labels=visa_df['continent'].unique()
for i in range(len(labels)):
    d[labels[i]]=i
visa_df['continent']=visa_df['continent'].map(d)
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          0           High School                  N
# 1         EZYV02          0              Master's                  Y
# 2         EZYV03          0            Bachelor's                  N
# 3         EZYV04          0            Bachelor's                  N
# 4         EZYV05          1              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          0            Bachelor's                  Y
# 25476  EZYV25477          0           High School                  Y
# 25477  EZYV25478          0              Master's                  Y
# 25478  EZYV25479          0              Master's                  Y
# 25479  EZYV25480          0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
d={'Asia':0, 'Africa':1, 'North America':2, 'Europe':3, 'South America':4,'Oceania':5}
visa_df['continent']=visa_df['continent'].map(d)

# %%
path=r"C:\Users\jeesh\OneDrive\Documents\NARESHIT\DATA FILES\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_cols=visa_df.select_dtypes(include='object').columns
d={}
for j in cat_cols[1:]:
    labels=visa_df['continent'].unique()
for i in range(len(labels)):
    d[labels[i]]=i
visa_df[j]=visa_df[j].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#we always drop the id columns
# id columns never provuide any information

# %% [markdown]
# ## **label encoder**

# %%
path=r"C:\Users\jeesh\OneDrive\Documents\NARESHIT\DATA FILES\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r"C:\Users\jeesh\OneDrive\Documents\NARESHIT\DATA FILES\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(path)
cat_cols=visa_df.select_dtypes(include='object').columns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in cat_cols:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# <img src="https://wallpapercave.com/wp/wp9337195.jpg" alt="Motivational Quote 4k Wallpapers - Wallpaper Cave" class=" nofocus" tabindex="0" aria-label="Motivational Quote 4k Wallpapers - Wallpaper Cave" role="button" data-bm="176">

# %%
le.inverse_transform(visa_df['continent'][:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 le.inverse_transform(visa_df['continent'])
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:160, in LabelEncoder.inverse_transform(self, y)
#     158 diff = np.setdiff1d(y, np.arange(len(self.classes_)))
#     159 if len(diff):
# --> 160     raise ValueError("y contains previously unseen labels: %s" % str(diff))
#     161 y = np.asarray(y)
#     162 return self.classes_[y]
#
# ValueError: y contains previously unseen labels: [2 3 4 5]

# %%
path=r"C:\Users\jeesh\OneDrive\Documents\NARESHIT\DATA FILES\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(path)
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['continent']=le.fit_transform(visa_df['continent'])

# %%
le.inverse_transform(visa_df['continent'])
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'], dtype=object)

# %% [markdown]
# ## **np.where**

# %% [markdown]
# - np.where required 3 arguments
#
# - condition
#
# - true
#
# - false
#
# - it is aplicable only for binary labels
#
# - case status has only two labels certified and denied
#
# - if case status == certified replace that as 0 , otherwise 1

# %%
path=r"C:\Users\jeesh\OneDrive\Documents\NARESHIT\DATA FILES\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(path)
con=visa_df['case_status']=='Certified'
visa_df['case_status']=np.where(con,0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ## ** one hot encoder**

# %% [markdown]
# $advanatges$

# %% [markdown]
# - when you devolop ml model it is very important the columns should be independent each other
#
# - so here case status creating two extra columns
#
# - which are independent each other , which means the row values at a time inly column has 1
#
# - columns are independent each other
#
# - which means 90 degrees phase shift
#
# - which means perpendicular each other
#
# - which mean orthoganal each other

# %% [markdown]
# $disadvantage$

# %% [markdown]
# - the disadvantage is if a column has 100 unique labels , 100 new columns will be created
#
# - the data will become sparse , which means huge
#
# - columns are more means, dimensions are more
#
# - the processing time is more
#
# - the memory consumption is more
#
# - **curse of dimensionality**

# %% [markdown]
# **pd.get_dummies**

# %%
path=r"C:\Users\jeesh\OneDrive\Documents\NARESHIT\DATA FILES\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(path)
pd.get_dummies(visa_df,columns=['case_status','education_of_employee'],
              dtype='int')
# Out:
#          case_id continent has_job_experience requires_job_training  \
# 0         EZYV01      Asia                  N                     N
# 1         EZYV02      Asia                  Y                     N
# 2         EZYV03      Asia                  N                     Y
# 3         EZYV04      Asia                  N                     N
# 4         EZYV05    Africa                  Y                     N
# ...          ...       ...                ...                   ...
# 25475  EZYV25476      Asia                  Y                     Y
# 25476  EZYV25477      Asia                  Y                     N
# 25477  EZYV25478      Asia                  Y                     N
# 25478  EZYV25479      Asia                  Y                     Y
# 25479  EZYV25480      Asia                  Y                     N
#
#        no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0                14513         2007                 West         592.2029
# ...

# %%
path=r"C:\Users\jeesh\OneDrive\Documents\NARESHIT\DATA FILES\Visadataset - Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df.drop('case_id',axis=1,inplace=True)
pd.get_dummies(visa_df,columns=['case_status','education_of_employee'],
              dtype='int')
# Out:
#       continent has_job_experience requires_job_training  no_of_employees  \
# 0          Asia                  N                     N            14513
# 1          Asia                  Y                     N             2412
# 2          Asia                  N                     Y            44444
# 3          Asia                  N                     N               98
# 4        Africa                  Y                     N             1082
# ...         ...                ...                   ...              ...
# 25475      Asia                  Y                     Y             2601
# 25476      Asia                  Y                     N             3274
# 25477      Asia                  Y                     N             1121
# 25478      Asia                  Y                     Y             1918
# 25479      Asia                  Y                     N             3195
#
#        yr_of_estab region_of_employment  prevailing_wage unit_of_wage  \
# ...

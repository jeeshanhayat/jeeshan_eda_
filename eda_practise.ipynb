# %%
import os
import pandas as pd
current_path = os.getcwd()
print(f"The current working directory (notebook path) is: {current_path}")
# Out:
# The current working directory (notebook path) is: C:\Users\jeesh\OneDrive\Documents\NARESHIT\EDA

# %%
path=r"C:\Users\jeesh\OneDrive\Documents\NARESHIT\DATA FILES\android-games - android-games.csv"

# %%
pd.read_csv(path)
# Out:
#       rank                                         title  total ratings  \
# 0        1                Garena Free Fire- World Series       86273129
# 1        2                        PUBG MOBILE - Traverse       37276732
# 2        3                     Mobile Legends: Bang Bang       26663595
# 3        4                                   Brawl Stars       17971552
# 4        5  Sniper 3D: Fun Free Online FPS Shooting Game       14464235
# ...    ...                                           ...            ...
# 1725    96                 زوايا - لعبة ستحرك زوايا عقلك         112408
# 1726    97     Bible Word Puzzle - Free Bible Word Games         111595
# 1727    98                  Scrabble® GO - New Word Game         110723
# 1728    99      Word Nut: Word Puzzle Games & Crosswords         109530
# 1729   100                                  Pinturillo 2         108917
#
#      installs  average rating  growth (30 days)  growth (60 days)  price  \
# ...

# %%
name=["jeeshan","aenul","pratham"]
age=[20,21,22]
name,age
# Out:
# (['jeeshan', 'aenul', 'pratham'], [20, 21, 22])

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(zip(name,age))
# Out:
#          0   1
# 0  jeeshan  20
# 1    aenul  21
# 2  pratham  22

# %%
pd.DataFrame(zip(name,age),columns=['name','age'])
                     #or
    
data=zip(name,age)
cols=['name','age']
pd.DataFrame(data,columns=cols)
# Out:
#       name  age
# 0  jeeshan   20
# 1    aenul   21
# 2  pratham   22

# %%
data=zip(name,age)
cols=['name','age']
pd.DataFrame(data,columns=cols)
# Out:
#       name  age
# 0  jeeshan   20
# 1    aenul   21
# 2  pratham   22

# %%
data=zip(name,age)
cols=['name','age']
ind=['A','B','C']
df=pd.DataFrame(data,columns=cols,index=ind)
df
# Out:
#       name  age
# A  jeeshan   20
# B    aenul   21
# C  pratham   22

# %%
citynames=['hyd','blr','del']
df['city']=citynames
df
# Out:
#       name  age city
# A   jeeshu   20  hyd
# B  pratham   21  blr
# C   irshad   22  del

# %%
df['name']=['jeeshu','pratham','irshad']
df
# Out:
#       name  age city
# A   jeeshu   20  hyd
# B  pratham   21  blr
# C   irshad   22  del

# %%
df
# Out:
#       name  age city
# A   jeeshu   20  hyd
# B  pratham   21  blr
# C   irshad   22  del

# %%
df.drop['city',
        axis = 1,
        inplace=True]
# Out:
#   Cell In[45], line 2
#     axis = 1,
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
df
# Out:
#       name  age
# A   jeeshu   20
# B  pratham   21
# C   irshad   22

# %%
df.drop['C',
        axis = 0,
        inplace=True]
# Out:
#   Cell In[51], line 2
#     axis = 0,
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# Out:
#       name  age
# A   jeeshu   20
# B  pratham   21
# C   irshad   22
